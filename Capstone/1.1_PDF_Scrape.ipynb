# %% [markdown]
# ## <font color="blue">1.1 - Cash Flow - PDF Scrape
# ---
# ### <font color="blue">Process from AnalyticsAriel Youtube Channel</font>
#
# ##### <font color="blue">This notebook was executed using Google Colab. My local Python Environment didn't have Java installed. Imports and exports were specific to Colab

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %%
# !pip install tabula-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 68.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ---
#
# ## <font color="blue">Imports<font>
# ---

# %%
import tabula
import warnings
import plotly.express as px
from datetime import datetime
from google.colab import drive, files, output # specific to Google Colab

warnings.filterwarnings('ignore')

# %% [markdown]
# ## <font color="blue">Data</font>

# %%
# Read in all 3 files
GE_2020 = "/content/sample_data/General_Election_2020.pdf"
CA_Recall_2021 = '/content/sample_data/CA_Recall_2021.pdf'
GE_2022 = '/content/sample_data/General_Election_2022.pdf'

table1 = tabula.read_pdf(GE_2020, pages=1)
table2 = tabula.read_pdf(CA_Recall_2021, pages=1)
table3 = tabula.read_pdf(GE_2022, pages=1)

table1[0]
# Out:
#          County  Number of Eligible to  Registered   Precinct Vote-By-Mail  \
# 0           NaN  Precincts    Register      Voters    Voters*       Voters
# 1           NaN        NaN         NaN         NaN        NaN          NaN
# 2       Alameda        521   1,092,044     966,809     56,810      728,405
# 3        Alpine          5         924         869        0**          749
# 4       Amador*         30      27,210      25,605      1,984       20,636
# ..          ...        ...         ...         ...        ...          ...
# 57      Ventura        695     537,055     500,442     45,455      384,467
# 58         Yolo         58     150,850     119,218      6,210       92,830
# 59         Yuba         34      51,819      39,626      4,186       26,015
# 60  State Total     20,497  25,090,517  22,047,448  2,361,850   15,423,301
# 61      Percent        NaN         NaN      87.87%     13.28%       86.72%
#
#          Total    Percent of     Turnout Turnout.1
# ...

# %%
table2[0]
# Out:
#          County  Number of Eligible to  Registered   Precinct Vote-By-Mail  \
# 0           NaN  Precincts    Register     Voters1    Voters*       Voters
# 1           NaN        NaN         NaN         NaN        NaN          NaN
# 2       Alameda        521   1,078,323     948,561     31,061      545,222
# 3       Alpine2          5         919         919        0**          581
# 4       Amador*         30      26,822      26,475        782       19,182
# ..          ...        ...         ...         ...        ...          ...
# 57      Ventura        697     532,017     509,797     31,002      290,551
# 58         Yolo         32     146,198     121,550      3,827       74,221
# 59         Yuba         36      51,930      40,997      2,241       21,094
# 60  State Total     18,185  24,819,858  22,057,154  1,159,149   11,733,429
# 61      Percent        NaN         NaN      88.87%      8.99%       91.01%
#
#          Total    Percent of     Turnout Turnout.1
# ...

# %%
table3[0]
# Out:
#          County  Number of Eligible to  Registered   Precinct Vote-By-Mail  \
# 0           NaN  Precincts    Register     Voters1    Voters*       Voters
# 1           NaN        NaN         NaN         NaN        NaN          NaN
# 2      Alameda*        552   1,140,774     931,130     38,308      457,817
# 3        Alpine          5       1,015         915        0**          623
# 4       Amador*         47      29,593      25,954      1,251       17,667
# ..          ...        ...         ...         ...        ...          ...
# 57     Ventura*      1,640     584,861     505,110     30,112      253,901
# 58        Yolo*         62     155,109     118,797      5,650       63,144
# 59         Yuba         35      56,463      41,212      2,537       17,349
# 60  State Total     25,554  26,876,800  21,940,274  1,391,422    9,755,188
# 61      Percent        NaN         NaN      81.63%     12.48%       87.52%
#
#          Total    Percent of     Turnout Turnout.1
# ...

# %%
# normalize data
GE_2020 = table1[0]
CA_Recall_2021 = table2[0]
GE_2022 = table3[0]

# %%
# export
GE_2020.to_csv('GE_2020.csv', index=False)
CA_Recall_2021.to_csv('CA_Recall_2021.csv', index=False)
GE_2022.to_csv('GE_2022.csv', index=False)
